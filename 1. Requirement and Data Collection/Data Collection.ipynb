# %% [markdown]
# ## Import Librarys

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Load the Data

# %%
dataset=pd.read_csv("insurance_claims.csv")

# %%
dataset
# Out:
#        policy_id  subscription_length  vehicle_age  customer_age region_code  \
# 0      POL045360                  9.3          1.2            41          C8
# 1      POL016745                  8.2          1.8            35          C2
# 2      POL007194                  9.5          0.2            44          C8
# 3      POL018146                  5.2          0.4            44         C10
# 4      POL049011                 10.1          1.0            56         C13
# ...          ...                  ...          ...           ...         ...
# 25344  POL029984                 12.3          1.8            43          C3
# 25345  POL014807                 12.2          0.2            40          C1
# 25346  POL039740                 12.1          1.8            57          C2
# 25347  POL056148                  3.9          2.2            48         C13
# 25348  POL033288                  0.2          0.0            41          C7
#
# ...
